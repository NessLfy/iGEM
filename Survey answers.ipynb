# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\nessl\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
df = pd.read_csv("Questionnaire ostréiculteurs.csv")

# %%
df["Horodateur"] = pd.to_datetime(df["Horodateur"])# change first column to date

# Replace NaN values by 0
for i in df.columns:
    df[i] = df[i].fillna(0)
    
df
# Out:
#                  Horodateur          Nom - Prénom Nom de ma ferme ostréicole  \
# 0 2022-07-23 20:31:48-02:00        Rousseau Éric       Earl huîtres rousseau
# 1 2022-07-23 22:30:08-02:00     Campagne Terence        Earl campagne & fils
# 2 2022-07-26 17:10:54-02:00                     0                          0
# 3 2022-07-27 14:58:00-02:00        JEAN -Frederic                          0
# 4 2022-07-27 15:01:28-02:00  Cessateur Alexandre                  Ostréisud
# 5 2022-07-29 09:14:45-02:00         Durand Samuel                 Philostrea
#
#   La ferme se situe dans la région  \
# 0                 Poitou-Charentes
# 1             Arcachon - Aquitaine
# 2             Arcachon - Aquitaine
# 3                     Méditerranée
# 4                     Méditerranée
# 5                     Bretagne sud
#
#   Si vous êtes situé dans la région méditerranéenne êtes vous situé sur le bassin de Thau ?  \
# 0                                                Non
# 1                                                  0
# 2                                                Non
# 3                                                Oui
# 4                                                Oui
# 5                                                  0
#
#   Je suis ostréiculteur depuis Je travaille seul(e) à ma ferme ostréicole  \
# 0               Plus de 10 ans                                        Non
# 1               Plus de 10 ans                                        Non
# 2               Plus de 10 ans                                        Non
# 3               Plus de 10 ans                                        Oui
# 4                   5 à 10 ans                                        Non
# 5                    3 à 5 ans                                        Non
#
#   La ferme est une ferme familiale  J'ai toujours exercé ce métier  \
# 0                               Oui                            Oui
# 1                               Oui                            Oui
# 2                               Oui                            Oui
# 3                               Oui                            Non
# 4                               Non                            Non
# 5                               Non                            Non
#
#   Dans ma ferme je cultive uniquement des huîtres  ...  \
# 0                                             Oui  ...
# 1                                             Oui  ...
# 2                                             Oui  ...
# 3                                             Non  ...
# 4                                             Non  ...
# 5                                             Non  ...
#
#   S'il le faut, je suis prêt(e) à réaliser des tests  \
# 0                                  Une fois par mois
# 1                                 Deux fois par mois
# 2                                  Une fois par mois
# 3                                  Une fois par mois
# 4                                 Deux fois par mois
# 5                         Plusieurs fois par semaine
#
#   Je trouve qu'il est contraignant de réaliser les tests moi-même  \
# 0                                                Oui
# 1                                                Non
# 2                                                Non
# 3                                                Non
# 4                                                Non
# 5                                                Non
#
#   Si oui, pourquoi ?.1 Quel prix MAXIMAL suis-je prêt(e) à payer UN test ?  \
# 0        Pas de temps                                                   5
# 1                    0                                                  5
# 2                    0                                                  2
# 3                    0                                                  2
# 4                    0                                                  5
# 5                    0                                                 10
#
#   Ouvrir une huître pour réaliser le test me pose problème   \
# 0                                                  1
# 1                                                  1
# 2                                                  5
# 3                                                  1
# 4                                                  1
# 5                                                  1
#
#   Le projet mérite d'aboutir à la vente du test   \
# 0                                              5
# 1                                              4
# 2                                              1
# 3                                              3
# 4                                              5
# 5                                              4
#
#   Si le test est en vente je l'achète Avez-vous des suggestions ? remarques ?  \
# 0                                 Oui                                     0.0
# 1         Peut être / après réflexion                                     0.0
# 2         Peut être / après réflexion                                     0.0
# 3         Peut être / après réflexion                                     0.0
# 4                                 Oui                                     0.0
# 5         Peut être / après réflexion                                     0.0
#
#   J'accepte d'être recontacté(e) pour un échange  \
# 0                                              0
# 1                                              0
# 2                                            Non
# 3                                            Oui
# 4                                            Oui
# 5                                            Oui
#
#   Si oui, veuillez renseigner votre adresse mail, téléphone...
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                             Jeanfrederic34@free.fr
# 4                                              Email
# 5                   federationconchylicole@gmail.com
#
# [6 rows x 32 columns]

# %%
## Location of the answers

# %%
li = [x for x in plt.hist(df[df.columns[3]])[0] if x != 0]
plt.close()
palette_color = sns.color_palette('pastel')
sns.set_context("talk")
plt.pie(li, labels=["Poitou-Charentes","Arcachon - Aquitaine","Méditerranée","Bretagne sud"], colors=palette_color, autopct='%.0f%%')
plt.savefig("images/survey/origin.png",dpi=300)
plt.show()

# %%
df[df.columns[3]]

plt.hist(df[df.columns[3]])
# Out:
# (array([1., 0., 0., 2., 0., 0., 2., 0., 0., 1.]),
#  array([0. , 0.3, 0.6, 0.9, 1.2, 1.5, 1.8, 2.1, 2.4, 2.7, 3. ]),
#  <BarContainer object of 10 artists>)

# %%
## Where them impacted by infections ?

# %%
positive = 0
tot= 0

for i in df[df.columns[11]]:
    if i == "Oui":
        positive+=1
    tot+=1


palette= sns.color_palette('pastel')
plt.pie([positive,0],colors=palette)
plt.legend(["Yes","No"])
plt.savefig("images/survey/impact.png",dpi=300)
plt.show()
